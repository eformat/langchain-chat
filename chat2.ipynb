# %%
# !pip install langchain-openai langchain langchain-classic panel
# Out:
# Requirement already satisfied: langchain-openai in ./venv/lib64/python3.13/site-packages (1.0.2)
# Requirement already satisfied: panel in ./venv/lib64/python3.13/site-packages (1.8.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.2 in ./venv/lib64/python3.13/site-packages (from langchain-openai) (1.0.5)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in ./venv/lib64/python3.13/site-packages (from langchain-openai) (2.8.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in ./venv/lib64/python3.13/site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: bleach in ./venv/lib64/python3.13/site-packages (from panel) (6.3.0)
# Requirement already satisfied: bokeh<3.9.0,>=3.7.0 in ./venv/lib64/python3.13/site-packages (from panel) (3.8.1)
# Requirement already satisfied: linkify-it-py in ./venv/lib64/python3.13/site-packages (from panel) (2.0.3)
# Requirement already satisfied: markdown in ./venv/lib64/python3.13/site-packages (from panel) (3.10)
# Requirement already satisfied: markdown-it-py in ./venv/lib64/python3.13/site-packages (from panel) (4.0.0)
# Requirement already satisfied: mdit-py-plugins in ./venv/lib64/python3.13/site-packages (from panel) (0.5.0)
# Requirement already satisfied: narwhals>=2 in ./venv/lib64/python3.13/site-packages (from panel) (2.11.0)
# Requirement already satisfied: packaging in ./venv/lib64/python3.13/site-packages (from panel) (25.0)
# Requirement already satisfied: pandas>=1.2 in ./venv/lib64/python3.13/site-packages (from panel) (2.3.3)
# Requirement already satisfied: param<3.0,>=2.1.0 in ./venv/lib64/python3.13/site-packages (from panel) (2.3.0)
# Requirement already satisfied: pyviz-comms>=2.0.0 in ./venv/lib64/python3.13/site-packages (from panel) (3.0.6)
# Requirement already satisfied: requests in ./venv/lib64/python3.13/site-packages (from panel) (2.32.5)
# Requirement already satisfied: tqdm in ./venv/lib64/python3.13/site-packages (from panel) (4.67.1)
# Requirement already satisfied: typing-extensions in ./venv/lib64/python3.13/site-packages (from panel) (4.15.0)
# Requirement already satisfied: Jinja2>=2.9 in ./venv/lib64/python3.13/site-packages (from bokeh<3.9.0,>=3.7.0->panel) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in ./venv/lib64/python3.13/site-packages (from bokeh<3.9.0,>=3.7.0->panel) (1.3.3)
# Requirement already satisfied: numpy>=1.16 in ./venv/lib64/python3.13/site-packages (from bokeh<3.9.0,>=3.7.0->panel) (2.3.4)
# Requirement already satisfied: pillow>=7.1.0 in ./venv/lib64/python3.13/site-packages (from bokeh<3.9.0,>=3.7.0->panel) (12.0.0)
# Requirement already satisfied: PyYAML>=3.10 in ./venv/lib64/python3.13/site-packages (from bokeh<3.9.0,>=3.7.0->panel) (6.0.3)
# Requirement already satisfied: tornado>=6.2 in ./venv/lib64/python3.13/site-packages (from bokeh<3.9.0,>=3.7.0->panel) (6.5.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in ./venv/lib64/python3.13/site-packages (from bokeh<3.9.0,>=3.7.0->panel) (2025.10.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./venv/lib64/python3.13/site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in ./venv/lib64/python3.13/site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.4.42)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./venv/lib64/python3.13/site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (2.12.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./venv/lib64/python3.13/site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (9.1.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./venv/lib64/python3.13/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./venv/lib64/python3.13/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./venv/lib64/python3.13/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in ./venv/lib64/python3.13/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: sniffio in ./venv/lib64/python3.13/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib64/python3.13/site-packages (from pandas>=1.2->panel) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib64/python3.13/site-packages (from pandas>=1.2->panel) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib64/python3.13/site-packages (from pandas>=1.2->panel) (2025.2)
# Requirement already satisfied: regex>=2022.1.18 in ./venv/lib64/python3.13/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib64/python3.13/site-packages (from requests->panel) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib64/python3.13/site-packages (from requests->panel) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib64/python3.13/site-packages (from requests->panel) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib64/python3.13/site-packages (from requests->panel) (2025.11.12)
# Requirement already satisfied: webencodings in ./venv/lib64/python3.13/site-packages (from bleach->panel) (0.5.1)
# Requirement already satisfied: uc-micro-py in ./venv/lib64/python3.13/site-packages (from linkify-it-py->panel) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in ./venv/lib64/python3.13/site-packages (from markdown-it-py->panel) (0.1.2)
# Requirement already satisfied: httpcore==1.* in ./venv/lib64/python3.13/site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./venv/lib64/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain-openai) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib64/python3.13/site-packages (from Jinja2>=2.9->bokeh<3.9.0,>=3.7.0->panel) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib64/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.2->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in ./venv/lib64/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./venv/lib64/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in ./venv/lib64/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib64/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./venv/lib64/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.2->langchain-openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv/lib64/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.4.2)
# Requirement already satisfied: six>=1.5 in ./venv/lib64/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.2->panel) (1.17.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
"""
Demonstrates how to use LangChain to wrap MaaS API with Panel's ChatInterface.

Highlights:

- Uses `PasswordInput` to set the API key, or uses the `OPENAI_API_KEY` environment variable.
- Uses `serialize` to get chat history from the `ChatInterface`.
- Uses `yield` to continuously concatenate the parts of the response
"""

from operator import itemgetter

import panel as pn
from langchain_classic.memory import ConversationTokenBufferMemory
from langchain_core.messages import AIMessage, HumanMessage
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
from langchain_openai import ChatOpenAI

pn.extension()


async def callback(contents: str, user: str, instance: pn.chat.ChatInterface):
    memory.clear()
    for message in instance.serialize():
        if message["role"] == "user":
            memory.chat_memory.add_user_message(HumanMessage(**message))
        else:
            memory.chat_memory.add_ai_message(AIMessage(**message))

    response = chain.astream({"user_input": contents})

    message = ""
    async for chunk in response:
        message += chunk
        yield message

llm = ChatOpenAI(
    streaming=True,
    model="llama-4-scout-17b-16e-w4a16",
    temperature=0.2,
    max_retries=2,
    base_url="",
    api_key=""
)

memory = ConversationTokenBufferMemory(
    return_messages=True,
    llm=llm,
    memory_key="chat_history",
    max_token_limit=8192 - 1024,
)
memory_link = RunnablePassthrough.assign(
    chat_history=RunnableLambda(memory.load_memory_variables)
    | itemgetter("chat_history")
)
prompt_link = ChatPromptTemplate.from_template(
    "{chat_history}\n\nBe a helpful chat bot and answer: {user_input}",
)
output_parser = StrOutputParser()

chain = (
    {"user_input": RunnablePassthrough()}
    | memory_link
    | prompt_link
    | llm
    | output_parser
)

chat_interface = pn.chat.ChatInterface(
    callback=callback,
    callback_user="Assistant",
    help_text="Send a message to get a reply from the Assistant",
    callback_exception="verbose",
)
template = pn.template.FastListTemplate(
    title="LangChain OpenAI",
    header_background="#E8B0E6",
    main=[chat_interface],
)
template.servable()
